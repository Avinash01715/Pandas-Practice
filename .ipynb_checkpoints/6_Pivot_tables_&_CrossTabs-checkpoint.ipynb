# %%
import numpy as np
import pandas as pd

# %%
# Sample Data
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    292     17   John  January      Q1
# 1  2023-01-02       B   West    252     25   Mary  January      Q1
# 2  2023-01-03       C  North    398     23    Bob  January      Q1
# 3  2023-01-04       D  South    529     42  Alice  January      Q1
# 4  2023-01-05       A   East    660     42   John  January      Q1
# 5  2023-01-06       B   West    430     21   Mary  January      Q1
# 6  2023-01-07       C  North    515     13    Bob  January      Q1
# 7  2023-01-08       D  South    627     55  Alice  January      Q1
# 8  2023-01-09       A   East    357     18   John  January      Q1
# 9  2023-01-10       B   West    133     62   Mary  January      Q1
# 10 2023-01-11       C  North    137     78    Bob  January      Q1
# 11 2023-01-12       D  South    643     75  Alice  January      Q1
# 12 2023-01-13       A   East    523     34   John  January      Q1
# 13 2023-01-14       B   West    436     90   Mary  January      Q1
# 14 2023-01-15       C  North    639     83    Bob  January      Q1
# 15 2023-01-16       D  South    855     10  Alice  January      Q1
# 16 2023-01-17       A   East    944     15   John  January      Q1
# 17 2023-01-18       B   West    257     78   Mary  January      Q1
# 18 2023-01-19       C  North    511     69    Bob  January      Q1
# 19 2023-01-20       D  South    634     86  Alice  January      Q1

# %% [markdown]
# *Pivot Table*

# %%
pt1 = pd.pivot_table(df, values="Sales", index="Region",columns="Product",aggfunc="sum")
pt1
# Out:
# Product       A       B       C       D
# Region
# East     2776.0     NaN     NaN     NaN
# North       NaN     NaN  2200.0     NaN
# South       NaN     NaN     NaN  3288.0
# West        NaN  1508.0     NaN     NaN

# %%
pt2 = pd.pivot_table(df,values=["Sales","Units"], index="Region",columns="Product")
pt2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     555.2    NaN    NaN    NaN  25.2   NaN   NaN   NaN
# North      NaN    NaN  440.0    NaN   NaN   NaN  53.2   NaN
# South      NaN    NaN    NaN  657.6   NaN   NaN   NaN  53.6
# West       NaN  301.6    NaN    NaN   NaN  55.2   NaN   NaN

# %% [markdown]
# *Cross Tabs*

# %%
pd.crosstab(df["Region"],df["Product"])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
